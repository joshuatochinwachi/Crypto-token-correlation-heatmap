# %% [markdown]
# ### Loading Joblib file

# %%
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the DataFrame
save_path = r"C:\Users\Jo$h\Desktop\Visual Studio Code\Token_heatmap\token_heatmap\Database\df_prices.joblib"
df_prices_loaded = joblib.load(save_path)

print(df_prices_loaded.head())
# Out:
#                            bitcoin     ethereum      solana    ripple
# timestamp
# 2025-07-08 14:00:00  109073.071447  2591.368899  152.116876  2.295713
# 2025-07-08 15:00:00  108406.174348  2564.814872  150.877537  2.282936
# 2025-07-08 16:00:00  108269.047177  2564.706990  149.886831  2.285550
# 2025-07-08 17:00:00  108416.673941  2576.406339  150.457441  2.290661
# 2025-07-08 18:00:00  108941.071726  2615.922574  152.059165  2.307880

# %% [markdown]
# ### Token Correlation Heatmap

# %%
# Calculate the correlation matrix
corr = df_prices_loaded.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Token Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Token Volatility

# %%
# Compute volatility (standard deviation of returns) for each token

# Calculate log returns
returns = df_prices_loaded.pct_change().apply(lambda x: np.log1p(x))

# Compute volatility (standard deviation of log returns)
volatility = returns.std()

print("Volatility for each token:")
print(volatility)
# Out:
# Volatility for each token:
# bitcoin     0.003264
# ethereum    0.006582
# solana      0.007039
# ripple      0.008564
# dtype: float64

# %% [markdown]
# ### Correlation of Tokens Return

# %%
print(returns.head())
# Out:
#                       bitcoin  ethereum    solana    ripple
# timestamp
# 2025-07-08 14:00:00       NaN       NaN       NaN       NaN
# 2025-07-08 15:00:00 -0.006133 -0.010300 -0.008181 -0.005581
# 2025-07-08 16:00:00 -0.001266 -0.000042 -0.006588  0.001144
# 2025-07-08 17:00:00  0.001363  0.004551  0.003800  0.002234
# 2025-07-08 18:00:00  0.004825  0.015221  0.010589  0.007489

# %%
# Calculate the correlation matrix
corr = returns.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Token Correlation Heatmap")
plt.show()
